# %% [markdown]
# Cal Poly Professor ratings scraped from https://polyratings.dev/search/name. Data collected + example:
#
# | LastName | FirstName | Department | Rating | NumRatings |
# | :------- | :-------- | :--------- | :----: | :--------: |
# | Doe      | John      | CSC        | 3.5    | 24         |

# %%
import pandas as pd
import itables
import json

# %%
# df_ratings = pd.read_json('professor_ratings.json')
# itables.show(df_ratings)

with open('professor_ratings.json') as f:
    data = json.load(f)

df_ratings = pd.json_normalize(data['data'])
columns = ["lastName", "firstName", "department", "numEvals", "overallRating", "materialClear", "studentDifficulties", "courses"]
df_ratings = df_ratings[columns]
itables.show(df_ratings)
# Out:
# <table id="itables_4087bebd_94b5_459b_a49c_7af1f098a1c9" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>lastName</th>
#       <th>firstName</th>
#       <th>department</th>
#       <th>numEvals</th>
#       <th>overallRating</th>
#       <th>materialClear</th>
#       <th>studentDifficulties</th>
#       <th>courses</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4087bebd_94b5_459b_a49c_7af1f098a1c9:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["Mahjoor", "Parisa", "CHEM", 17, 0.64, 0.82, 0.45, "[CHEM 110, CHEM 127, CHEM 316]"], ["Clark", "Chris", "CSC", 12, 3.7, 3.62, 3.7, "[CPE 103, CSC 103, CPE 123, CRP 430, CPE 481, CRP 420]"], ["LaGuire", "Tiev", "FSN", 13, 2.57, 2.57, 2.71, "[FSN 210, FSN 250, FSN 251]"], ["Lathrop", "Amanda", "FSN", 8, 2.22, 2.67, 1.89, "[FSN 125, FSN 275]"], ["Rucci", "Nancy", "SPAN", 12, 2.5, 2.5, 2.64, "[SPAN 101, SPAN 102, SPAN 111, SPAN 201, SPAN 202, SPAN 203]"], ["Ngoh", "Cheryl-lyn", "BUS", 1, 1.0, 3.0, 2.0, "[BUS]"], ["Athey", "Jean", "BUS", 5, 2.0, 2.44, 2.11, "[BUS 291, BUS 391]"], ["Clarke", "Jefferson", "ART", 12, 2.58, 3.11, 3.21, "[ART 101, ART 121, ART 122, ART 182, ART 221, ART 222]"], ["Roberts", "Mark", "ENGL", 205, 3.82, 3.89, 3.84, "[ENGL 101, ENGL 114, ENGL 134, ENGL 143, ENGL 145, HNRS 145, ENGL 201, ENGL 215, ENGL 251, ENGL 253, ENGL 302]"], ["Drasco", "Steve", "PHYS", 24, 2.26, 2.33, 2.19, "[ASTR 101, PHYS 132, PHYS 133, PHYS 141, PHYS 211]"], ["Glover", "Allan", "ME", 1, 4.0, 3.0, 4.0, "[ME]"], ["Neveu", "Marc J.", "ARCH", 22, 2.91, 2.96, 2.57, "[ARCH 218, ARCH 219, ARCH 351, ARCH 420]"], ["Granados", "Victor", "MATE", 24, 1.96, 1.81, 2.07, "[MATE 210, MATE 215, MATE 225, MATE 470]"], ["DeJong", "Alvin", "BIO", 29, 2.77, 2.74, 2.26, "[BIO 115, BIO 145, BIO 151, BIO 153, BIO 161, BIO 361, BIO 431, BIO 432, BIO 433]"], ["Taufik", "Taufik", "EE", 2, 4.0, 4.0, 4.0, "[EE 302, EE 212]"], ["Carroll", "Darrian", "COMS", 4, 4.0, 4.0, 4.0, "[COMS 332, COMS 205, COMS 435]"], ["Cirovic", "Michael", "EE", 24, 1.39, 1.57, 1.43, "[EE 109, EE 110, EE 309, EE 409, EE 460]"], ["Kaprielian", "Gabriel", "ARCH", 1, 3.0, 2.5, 2.5, "[ARCH 253]"], ["Peterson", "Daniel", "ASCI", 33, 2.8, 3.0, 2.68, "[ASCI 112, ASCI 211, ASCI 304, ASCI 320, ASCI 403, ASCI 476, ASCI 479]"], ["Chroman", "Tanya", "SPAN", 21, 3.34, 3.43, 3.43, "[SPAN 101, SPAN 102, SPAN 103, SPAN 124, SPAN 202, SPAN 203]"], ["Douglas", "Andrew Timothy", "PHYS", 55, 2.55, 2.41, 2.46, "[PHYS 121, PHYS 122, PHYS 123, PHYS 132, PHYS 133, PHYS 141]"], ["Bracco", "Angela", "ARCH", 19, 3.23, 2.91, 3.05, "[ARCH 131, ARCH 132, ARCH 133, ARCH 251, ARCH 252]"], ["Hurt", "Shelley", "POLS", 90, 1.82, 1.86, 1.78, "[POLS 111, POLS 225, POLS 325, POLS 333, POLS 420, POLS 421, POLS 426, POLS 451, POLS 461]"], ["Rachman", "Kyle", "MATH", 2, 4.0, 3.0, 4.0, "[MATH 118]"], ["Soto", "Carlos", "ME", 2, 3.0, 3.0, 3.0, "[ME, ME 228]"], ["Chen", "Lei-da", "BUS", 10, 3.55, 3.45, 3.45, "[BUS 319, BUS 391, BUS 491]"], ["Bates", "G.W.", "BRAE", 13, 2.87, 2.73, 2.73, "[BRAE 232, BRAE 237, BRAE 239]"], ["Keller", "John", "PHYS", 22, 3.36, 3.28, 3.44, "[PSC 101, ASTR 102, PHYS 103, PSC 103, PHYS 133, ASTR 301]"], ["Schoonover", "Rod", "CHEM", 208, 3.74, 3.74, 3.67, "[CHEM 111, CHEM 124, CHEM 125, CHEM 127, CHEM 128, CHEM 129, CHEM 138, CHEM 305, CHEM 312, CHEM 350, CHEM 351, CHEM 352, CHEM 353, CHEM 355, CHEM 405]"], ["Dobson", "John", "BUS", 70, 2.7, 2.54, 2.67, "[BUS 301, BUS 342, BUS 346, BUS 404, BUS 436, BUS 443, BUS 445, BUS 498]"], ["Preston", "William", "SOC", 63, 3.5, 3.65, 3.48, "[ENVE 144, GEOG 250, GEOG 308, SOC 308, GEOG 315, GEOG 325, GEOG 333, SOC 333, POLS 350]"], ["Nolan", "Frank", "COMS", 104, 3.03, 2.96, 2.87, "[SPC 101, SPC 125, PHIL 126, SCM 126, CM 145, COMS 145, ENGL 145, SCM 145, SPC 145, SPC 201]"], ["Brown", "J. Wyatt", "AEPS", 27, 2.0, 2.28, 1.69, "[FRSC 110, CRSC 120, CRSC 190, VGSC 190, CRSC 210, VGSC 220, CRSC 230, VGSC 230, VGSC 231, CRSC 232, CRSC 250, CRSC 401, CRSC 421, FRSC 461]"], ["Mitra", "Nalinjan", "CE", 9, 1.67, 1.67, 1.58, "[CE 207, CE 259]"], ["Beglin", "Katherine", "ENGL", 2, 3.33, 2.67, 3.0, "[ENGL 134]"], ["Al-Nakib", "Farah", "HIST", 1, 4.0, 4.0, 4.0, "[HIST 313]"], ["Chatziioanou", "Alypios", "CE", 22, 3.22, 3.13, 3.09, "[CE 112, CE 114, CE 221, CE 322, CE 525]"], ["Winn", "Michael", "ENGL", 109, 2.65, 2.66, 2.68, "[CM 101, COMS 101, ENGL 101, SCM 101, SPC 101, CM 102, COMS 102, ENGL 102, SCM 102, SCM 112]"], ["Comelli", "Isaac", "MATH", 1, 2. ...

# %%
# headers = {
#     'User-Agent': r"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 " ,
#     'Accept-Language': 'en-US,en;q=0.5'
# }
# url = "https://polyratings.dev/search/name"
# response = requests.get(url, headers=headers)
# soup = BeautifulSoup(response.content, "html.parser")
# print(soup)
# with open("temp.txt", "w") as file:
    # file.write(soup.text)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="/assets/favicon-444ba34f.ico" rel="icon" type="image/x-icon"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Cal Poly Professor Rating Website" name="description"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Nunito:ital,wght@0,400;0,500;0,600;0,700;0,900;1,300;1,400;1,500;1,600;1,800&amp;display=swap" rel="stylesheet"/>
# <title>Polyratings</title>
# <script crossorigin="" src="/assets/index-06032b6e.js" type="module"></script>
# <link href="/assets/index-c16748de.css" rel="stylesheet"/>
# </head>
# <body>
# <div id="root"></div>
# <!-- Cloudflare Pages Analytics --><script data-cf-beacon='{"token": "e00e796f50f8426da8488434d35cfc19"}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js"></script><!-- Cloudflare Pages Analytics --></body>
# </html>

# %%
# chunk = soup.find('div', class_="relative")
# print(chunk)
# profs = chunk.find_all('a', href="/professor/0038ea39-3910-4f80-9353-41dce33c754d")
# print(profs[0])
# for prof in profs:
# Out:
# None
